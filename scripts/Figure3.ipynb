# %%
from tqdm import tqdm
import pyarrow.parquet as pq
import random
import sys
from bisect import bisect_right
sys.path.insert(0, '/private/groups/brookslab/gabai/tools/NEMO/src/')
import importlib
from predict import *
from plot import *
importlib.reload(sys.modules['predict'])
importlib.reload(sys.modules['plot'])
from predict import *
from plot import *

# %%
dt_outpath = '../data/'
fig_outpath = '../figures/manuscript_figures/'
gtfFile = '/private/groups/brookslab/gabai/projects/Add-seq/data/ref/Saccharomyces_cerevisiae.R64-1-1.109.gtf'

chrom_190429_pred = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/modPredict/240905_prediction/240912_dorado_20190429_chrom.tsv'
chrom_210615_pred = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/modPredict/240905_prediction/240917_dorado_20210615_full.tsv'
chrom_sphe_pred = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/modPredict/240905_prediction/240909_dorado_sphe_using_nuclei_model.tsv'

# %%
# genes to plot
all_genes = {'CLN2':'chrXVI:66400-67550', 'ZDS2': 'chrXIII:51200-52700', 'NUP170':'chrII:74300-75800', 'APC1':'chrXIV:309955-311155', 
             'RPS14B':'chrX:73214-74414', 'zz-YIL161W':'chrIX:38868-40068', 'RDN':'chrXII:451060-468140', 
             'SMC4': 'chrXII:301632-302832', 'GLE1': 'chrIV:87675-88875', 'SPT6':'chrVII:719793-720993', 
             'VPS75':'chrXIV:184892-186092', 'FEX2': 'chrXVI:13765-14965'}

# %% [markdown]
# - Figure3A: rep1 aggregate
# - Figure3B: zz-YIL161W
# - Figure3C: SLM1
# - Figrue3D: CLN2
# - Figrue3E: NUP170

# %% [markdown]
# ## Figure 3B

# %%
plotModTrack(chrom_210615_pred, all_genes['zz-YIL161W'], ncluster=2, outpath=fig_outpath, prefix= f'Figure3B', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.4)

# %% [markdown]
# ## Figure3C

# %%
plotModTrack(chrom_190429_pred, all_genes['FEX2'], ncluster=2, outpath=fig_outpath, prefix= f'Figure3C', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.2)

# %% [markdown]
# ## Figure 3D

# %%
plotModTrack(chrom_210615_pred, all_genes['CLN2'], ncluster=2, outpath=fig_outpath, prefix= f'Figure3D', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.4)

# %% [markdown]
# ## Figrue 3E

# %%
plotModTrack(chrom_190429_pred, all_genes['NUP170'], ncluster=3, outpath=fig_outpath, prefix= f'Figure3E', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.4)
# Out:
# preprocessing input matrix...
# number of reads before filtering: 46
# number of reads kept: 31
# filtering hyper-methylated reads...
# number of reads kept: 29
# writing output to file:  ../figures/manuscript_figures/Figure3E_chrII:74300-75800.mtx
# nan in output matrix!
# running hierarchical clustering...
# Clustering with number of clusters = 3
# plotting gene annotations...

# %% [markdown]
# ## Create top track only

# %%
plotModTrack(chrom_210615_pred, all_genes['zz-YIL161W'], ncluster=2, outpath=fig_outpath, prefix= f'Figure3B_agg_only', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.4)
plotModTrack(chrom_190429_pred, all_genes['FEX2'], ncluster=2, outpath=fig_outpath, prefix= f'Figure3C_agg_only', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.2)
plotModTrack(chrom_210615_pred, all_genes['CLN2'], ncluster=2, outpath=fig_outpath, prefix= f'Figure3D_agg_only', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.4)
plotModTrack(chrom_190429_pred, all_genes['NUP170'], ncluster=3, outpath=fig_outpath, prefix= f'Figure3E_agg_only', 
             gtfFile=gtfFile, xticks_space = 150, na_thred=0.4)
# Out:
# preprocessing input matrix...
# number of reads before filtering: 203
# number of reads kept: 42
# filtering hyper-methylated reads...
# number of reads kept: 36
# writing output to file:  ../figures/manuscript_figures/Figure3B_agg_only_chrIX:38868-40068.mtx
# nan in output matrix!
# running hierarchical clustering...
# Clustering with number of clusters = 2
# plotting gene annotations...
# preprocessing input matrix...
# number of reads before filtering: 114
# number of reads kept: 95
# filtering hyper-methylated reads...
# number of reads kept: 89
# writing output to file:  ../figures/manuscript_figures/Figure3C_agg_only_chrXVI:13765-14965.mtx
# nan in output matrix!
# running hierarchical clustering...
# Clustering with number of clusters = 2
# plotting gene annotations...
# preprocessing input matrix...
# number of reads before filtering: 199
# number of reads kept: 43
# filtering hyper-methylated reads...
# number of reads kept: 36
# writing output to file:  ../figures/manuscript_figures/Figure3D_agg_only_chrXVI:66400-67550.mtx
# nan in output matrix!
# running hierarchical clustering...
# Clustering with number of clusters = 2
# plotting gene annotations...
# preprocessing input matrix...
# number of reads before filtering: 46
# number of reads kept: 31
# filtering hyper-methylated reads...
# number of reads kept: 29
# writing output to file:  ../figures/manuscript_figures/Figure3E_agg_only_chrII:74300-75800.mtx
# nan in output matrix!
# running hierarchical clustering...
# Clustering with number of clusters = 3
# plotting gene annotations...
